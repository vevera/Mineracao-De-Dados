# %%
import pandas as pd
import numpy as np
from apyori import apriori
import unidecode

# %%
def removeBadCharacters(word):
    
    bad_symbols = ".,?!@$&*()\/{}{}".format("'", '"')
    
    #removendo caracteres ruins
    clean_word = word.translate({ord(c): None for c in bad_symbols})
    
    #tornando a string unicode
    clean_word = unidecode.unidecode(clean_word)
    
    return clean_word

# %%
STOPWORDS = ['lei','rouanet','?','faz','.','assim','a','eles','ate','via','pelo','-','ela','ta','era',
             'quem','eu','tá','foi','pela','ser',',','tem','só','sem','vai',
             'é','e','ne','né','isso','onde','estão','esta','está','ver','pq','essa','vez','nas',
             'mas','qual','porque','ele','ter','pois','este','vez','q',
             'para','já','aos','pode','outro',
             'pra','desse','alguns','meio','entre','das',
             'podem','esse','seu','também','são','quando','de', 
             'que','em','os','as','da','como','dos','ou','se','um',
             'uma','para','na','ao','mais','por','não','ainda','muito','sua','a',
             'vc','voce','o','a','você','ai','aí','vocês','vcs','fazer','usou',"do","com","nao"]

# %%
tweets_data = pd.read_csv('lei_rouanet_final.csv')
tweets_data['dia'] = pd.to_datetime(tweets_data['dia'])

tweets_2019 = tweets_data.loc[(tweets_data['dia'] >= "01/01/2019") & (tweets_data['dia'] <= "31/12/2019")]["tweet"].values
tweets_2020 = tweets_data.loc[(tweets_data['dia'] >= "01/01/2020") & (tweets_data['dia'] <= "31/12/2020")]["tweet"].values
tweets_2021 = tweets_data.loc[(tweets_data['dia'] >= "01/01/2021") & (tweets_data['dia'] <= "31/12/2021")]["tweet"].values

# %%
len(tweets_2019)
# Out:
# 9559

# %%
len(tweets_2020)
# Out:
# 3921

# %%
len(tweets_2021)
# Out:
# 2985

# %%
import math

def getAssociationRules(vetor_tweets, min_support, min_confidence, min_lift, min_length, max_length):
    
    tweets_lists = []

    #Gerando um vetor de tweets, com cada palavra separada dentro de uma lista
    for tweet in vetor_tweets:
        
        tweet = tweet.lower()
        tweet_words = tweet.split()
        tweet_words = list(dict.fromkeys(tweet_words))
        new_tweet_list = []
        
        for word in tweet_words:
            word = removeBadCharacters(word)
            if word.strip() not in STOPWORDS:
                new_tweet_list.append(word)

        tweets_lists.append(new_tweet_list)
       
   
    #Chamando o apriori
    association_rules = apriori(tweets_lists, min_support=min_support, min_confidence=min_confidence, 
                                min_lift=min_lift, max_length=max_length)
    
    association_rules = filter(lambda x: len(x.items) >=  min_length, association_rules)

    #Mostrando Resultado
    for item in association_rules:
        
        print("\n")

        print("Palavras Associadas: ", list(item.items), " Support: ", item.support)

        print("----------------------------------------------------------------------------------\n")


        ordered_statistics = item.ordered_statistics

        for statistic in ordered_statistics:
            if(len(list(statistic.items_base)) <= math.floor(min_length/2)):
                print("{} -> {}".format(list(statistic.items_base),list(statistic.items_add)))
                print("Confidence: ", statistic.confidence)
                print("Lift: {}\n".format(statistic.lift))


        print("----------------------------------------------------------------------------------\n")

    print("Concluido!")

# %%
getAssociationRules(tweets_2020, 0.017, 0.7, 2, 9, 10)
# Out:
# Palavras Associadas:  ['boca', '15', 'fraudes', 'livre', 'apura', 'federal', 'policia', 'anos', 'operacao']  Support:  0.01734251466462637
# ----------------------------------------------------------------------------------
#
# ['15'] -> ['boca', 'fraudes', 'livre', 'apura', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.7640449438202247
# Lift: 44.056179775280896
#
# ['apura'] -> ['boca', '15', 'fraudes', 'livre', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.8831168831168832
# Lift: 50.184076792772444
#
# ['fraudes'] -> ['boca', '15', 'livre', 'apura', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.7391304347826088
# Lift: 42.619565217391305
#
# ['livre'] -> ['boca', '15', 'fraudes', 'apura', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.7391304347826088
# Lift: 42.619565217391305
#
# ['operacao'] -> ['boca', '15', 'fraudes', 'livre', 'apura', 'federal', 'policia', 'anos']
# Confidence:  0.7010309278350516
# Lift: 40.422680412371136
#
# ['policia'] -> ['boca', '15', 'fraudes', 'livre', 'apura', 'federal', 'anos', 'operacao']
# Confidence:  0.8292682926829269
# Lift: 47.81707317073171
#
# ['15', 'anos'] -> ['boca', 'fraudes', 'livre', 'apura', 'federal', 'policia', 'operacao']
# Confidence:  0.8095238095238095
# Lift: 46.67857142857143
#
# ['15', 'apura'] -> ['boca', 'fraudes', 'livre', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.8831168831168832
# Lift: 50.184076792772444
#
# ['boca', '15'] -> ['fraudes', 'livre', 'apura', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9315068493150684
# Lift: 53.71232876712328
#
# ['federal', '15'] -> ['boca', 'fraudes', 'livre', 'apura', 'policia', 'anos', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 51.5921052631579
#
# ['fraudes', '15'] -> ['boca', 'livre', 'apura', 'policia', 'federal', 'anos', 'operacao']
# Confidence:  0.8607594936708861
# Lift: 49.63291139240506
#
# ['livre', '15'] -> ['boca', 'fraudes', 'apura', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9444444444444444
# Lift: 54.45833333333333
#
# ['15', 'operacao'] -> ['boca', 'fraudes', 'livre', 'apura', 'federal', 'policia', 'anos']
# Confidence:  0.8500000000000001
# Lift: 49.0125
#
# ['policia', '15'] -> ['boca', 'fraudes', 'livre', 'apura', 'federal', 'anos', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 51.5921052631579
#
# ['apura', 'anos'] -> ['boca', '15', 'fraudes', 'livre', 'federal', 'policia', 'operacao']
# Confidence:  0.8831168831168832
# Lift: 50.184076792772444
#
# ['boca', 'anos'] -> ['15', 'fraudes', 'livre', 'apura', 'federal', 'policia', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 52.986486486486484
#
# ['federal', 'anos'] -> ['boca', '15', 'fraudes', 'livre', 'apura', 'policia', 'operacao']
# Confidence:  0.8831168831168832
# Lift: 50.922077922077925
#
# ['fraudes', 'anos'] -> ['boca', '15', 'livre', 'apura', 'federal', 'policia', 'operacao']
# Confidence:  0.8607594936708861
# Lift: 49.63291139240506
#
# ['livre', 'anos'] -> ['boca', '15', 'fraudes', 'apura', 'federal', 'policia', 'operacao']
# Confidence:  0.9315068493150684
# Lift: 53.71232876712328
#
# ['anos', 'operacao'] -> ['boca', '15', 'fraudes', 'livre', 'apura', 'federal', 'policia']
# Confidence:  0.8500000000000001
# Lift: 49.0125
#
# ['policia', 'anos'] -> ['boca', '15', 'fraudes', 'livre', 'apura', 'federal', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 51.5921052631579
#
# ['boca', 'apura'] -> ['15', 'fraudes', 'livre', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9577464788732394
# Lift: 54.42498469075321
#
# ['federal', 'apura'] -> ['boca', '15', 'fraudes', 'livre', 'policia', 'anos', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 52.21856639247943
#
# ['fraudes', 'apura'] -> ['boca', '15', 'livre', 'policia', 'federal', 'anos', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 50.84439359267735
#
# ['livre', 'apura'] -> ['boca', '15', 'fraudes', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 55.20248447204969
#
# ['apura', 'operacao'] -> ['boca', '15', 'fraudes', 'livre', 'federal', 'policia', 'anos']
# Confidence:  0.8947368421052633
# Lift: 50.84439359267735
#
# ['policia', 'apura'] -> ['boca', '15', 'fraudes', 'livre', 'federal', 'anos', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 52.21856639247943
#
# ['federal', 'boca'] -> ['15', 'fraudes', 'livre', 'apura', 'policia', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 56.01428571428571
#
# ['fraudes', 'boca'] -> ['15', 'livre', 'apura', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9577464788732394
# Lift: 55.22535211267605
#
# ['boca', 'livre'] -> ['15', 'fraudes', 'apura', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 49.357275083302476
#
# ['boca', 'operacao'] -> ['15', 'fraudes', 'livre', 'apura', 'federal', 'policia', 'anos']
# Confidence:  0.9066666666666667
# Lift: 52.28
#
# ['policia', 'boca'] -> ['15', 'fraudes', 'livre', 'apura', 'federal', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 56.01428571428571
#
# ['fraudes', 'federal'] -> ['boca', '15', 'livre', 'apura', 'policia', 'anos', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 51.5921052631579
#
# ['federal', 'livre'] -> ['boca', '15', 'fraudes', 'apura', 'policia', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 56.01428571428571
#
# ['federal', 'operacao'] -> ['boca', '15', 'fraudes', 'livre', 'apura', 'policia', 'anos']
# Confidence:  0.8717948717948718
# Lift: 50.26923076923077
#
# ['federal', 'policia'] -> ['boca', '15', 'fraudes', 'livre', 'apura', 'anos', 'operacao']
# Confidence:  0.8500000000000001
# Lift: 48.30217391304348
#
# ['fraudes', 'livre'] -> ['boca', '15', 'apura', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 56.01428571428571
#
# ['fraudes', 'operacao'] -> ['boca', '15', 'livre', 'apura', 'federal', 'policia', 'anos']
# Confidence:  0.7816091954022988
# Lift: 45.068965517241374
#
# ['fraudes', 'policia'] -> ['boca', '15', 'livre', 'apura', 'federal', 'anos', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 51.5921052631579
#
# ['livre', 'operacao'] -> ['boca', '15', 'fraudes', 'apura', 'federal', 'policia', 'anos']
# Confidence:  0.9315068493150684
# Lift: 53.71232876712328
#
# ['policia', 'livre'] -> ['boca', '15', 'fraudes', 'apura', 'federal', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 56.01428571428571
#
# ['policia', 'operacao'] -> ['boca', '15', 'fraudes', 'livre', 'apura', 'federal', 'anos']
# Confidence:  0.8717948717948718
# Lift: 50.26923076923077
#
# ['apura', '15', 'anos'] -> ['boca', 'fraudes', 'livre', 'federal', 'policia', 'operacao']
# Confidence:  0.8831168831168832
# Lift: 50.184076792772444
#
# ['boca', '15', 'anos'] -> ['fraudes', 'livre', 'apura', 'federal', 'policia', 'operacao']
# Confidence:  0.9315068493150684
# Lift: 53.71232876712328
#
# ['federal', '15', 'anos'] -> ['boca', 'fraudes', 'livre', 'apura', 'policia', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 51.5921052631579
#
# ['fraudes', '15', 'anos'] -> ['boca', 'livre', 'apura', 'policia', 'federal', 'operacao']
# Confidence:  0.8607594936708861
# Lift: 49.63291139240506
#
# ['livre', '15', 'anos'] -> ['boca', 'fraudes', 'apura', 'federal', 'policia', 'operacao']
# Confidence:  0.9444444444444444
# Lift: 54.45833333333333
#
# ['15', 'anos', 'operacao'] -> ['boca', 'fraudes', 'livre', 'apura', 'federal', 'policia']
# Confidence:  0.8500000000000001
# Lift: 49.0125
#
# ['policia', '15', 'anos'] -> ['boca', 'fraudes', 'livre', 'apura', 'federal', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 51.5921052631579
#
# ['boca', '15', 'apura'] -> ['fraudes', 'livre', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9577464788732394
# Lift: 54.42498469075321
#
# ['federal', '15', 'apura'] -> ['boca', 'fraudes', 'livre', 'policia', 'anos', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 52.21856639247943
#
# ['fraudes', '15', 'apura'] -> ['boca', 'livre', 'policia', 'federal', 'anos', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 50.84439359267735
#
# ['livre', '15', 'apura'] -> ['boca', 'fraudes', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 55.20248447204969
#
# ['15', 'apura', 'operacao'] -> ['boca', 'fraudes', 'livre', 'federal', 'policia', 'anos']
# Confidence:  0.8947368421052633
# Lift: 50.84439359267735
#
# ['policia', '15', 'apura'] -> ['boca', 'fraudes', 'livre', 'federal', 'anos', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 52.21856639247943
#
# ['federal', 'boca', '15'] -> ['fraudes', 'livre', 'apura', 'policia', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['fraudes', 'boca', '15'] -> ['livre', 'apura', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9577464788732394
# Lift: 55.22535211267605
#
# ['boca', '15', 'livre'] -> ['fraudes', 'apura', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9444444444444444
# Lift: 50.7283105022831
#
# ['boca', '15', 'operacao'] -> ['fraudes', 'livre', 'apura', 'federal', 'policia', 'anos']
# Confidence:  0.9315068493150684
# Lift: 53.71232876712328
#
# ['policia', 'boca', '15'] -> ['fraudes', 'livre', 'apura', 'federal', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['fraudes', 'federal', '15'] -> ['boca', 'livre', 'apura', 'policia', 'anos', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 51.5921052631579
#
# ['federal', 'livre', '15'] -> ['boca', 'fraudes', 'apura', 'policia', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['federal', '15', 'operacao'] -> ['boca', 'fraudes', 'livre', 'apura', 'policia', 'anos']
# Confidence:  0.9066666666666667
# Lift: 52.28
#
# ['federal', '15', 'policia'] -> ['boca', 'fraudes', 'livre', 'apura', 'anos', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 50.84439359267735
#
# ['fraudes', 'livre', '15'] -> ['boca', 'apura', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 56.01428571428571
#
# ['fraudes', '15', 'operacao'] -> ['boca', 'livre', 'apura', 'policia', 'federal', 'anos']
# Confidence:  0.8717948717948718
# Lift: 50.26923076923077
#
# ['fraudes', 'policia', '15'] -> ['boca', 'livre', 'apura', 'federal', 'anos', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 51.5921052631579
#
# ['livre', '15', 'operacao'] -> ['boca', 'fraudes', 'apura', 'federal', 'policia', 'anos']
# Confidence:  0.9444444444444444
# Lift: 54.45833333333333
#
# ['policia', 'livre', '15'] -> ['boca', 'fraudes', 'apura', 'federal', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['policia', '15', 'operacao'] -> ['boca', 'fraudes', 'livre', 'apura', 'federal', 'anos']
# Confidence:  0.9066666666666667
# Lift: 52.28
#
# ['apura', 'boca', 'anos'] -> ['15', 'fraudes', 'livre', 'federal', 'policia', 'operacao']
# Confidence:  0.9577464788732394
# Lift: 54.42498469075321
#
# ['apura', 'anos', 'federal'] -> ['boca', '15', 'fraudes', 'livre', 'policia', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 52.21856639247943
#
# ['fraudes', 'apura', 'anos'] -> ['boca', '15', 'livre', 'policia', 'federal', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 50.84439359267735
#
# ['apura', 'livre', 'anos'] -> ['boca', '15', 'fraudes', 'federal', 'policia', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 55.20248447204969
#
# ['apura', 'anos', 'operacao'] -> ['boca', '15', 'fraudes', 'livre', 'federal', 'policia']
# Confidence:  0.8947368421052633
# Lift: 50.84439359267735
#
# ['apura', 'anos', 'policia'] -> ['boca', '15', 'fraudes', 'livre', 'federal', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 52.21856639247943
#
# ['federal', 'boca', 'anos'] -> ['15', 'fraudes', 'livre', 'apura', 'policia', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['fraudes', 'boca', 'anos'] -> ['15', 'livre', 'apura', 'federal', 'policia', 'operacao']
# Confidence:  0.9577464788732394
# Lift: 55.22535211267605
#
# ['boca', 'anos', 'livre'] -> ['15', 'fraudes', 'apura', 'federal', 'policia', 'operacao']
# Confidence:  0.9444444444444444
# Lift: 50.7283105022831
#
# ['boca', 'anos', 'operacao'] -> ['15', 'fraudes', 'livre', 'apura', 'federal', 'policia']
# Confidence:  0.9315068493150684
# Lift: 53.71232876712328
#
# ['policia', 'boca', 'anos'] -> ['15', 'fraudes', 'livre', 'apura', 'federal', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['fraudes', 'federal', 'anos'] -> ['boca', '15', 'livre', 'apura', 'policia', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 51.5921052631579
#
# ['federal', 'livre', 'anos'] -> ['boca', '15', 'fraudes', 'apura', 'policia', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['federal', 'anos', 'operacao'] -> ['boca', '15', 'fraudes', 'livre', 'apura', 'policia']
# Confidence:  0.9066666666666667
# Lift: 52.28
#
# ['federal', 'anos', 'policia'] -> ['boca', '15', 'fraudes', 'livre', 'apura', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 50.84439359267735
#
# ['fraudes', 'livre', 'anos'] -> ['boca', '15', 'apura', 'federal', 'policia', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 56.01428571428571
#
# ['fraudes', 'anos', 'operacao'] -> ['boca', '15', 'livre', 'apura', 'federal', 'policia']
# Confidence:  0.8717948717948718
# Lift: 50.26923076923077
#
# ['fraudes', 'policia', 'anos'] -> ['boca', '15', 'livre', 'apura', 'federal', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 51.5921052631579
#
# ['livre', 'anos', 'operacao'] -> ['boca', '15', 'fraudes', 'apura', 'federal', 'policia']
# Confidence:  0.9444444444444444
# Lift: 54.45833333333333
#
# ['policia', 'livre', 'anos'] -> ['boca', '15', 'fraudes', 'apura', 'federal', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['policia', 'anos', 'operacao'] -> ['boca', '15', 'fraudes', 'livre', 'apura', 'federal']
# Confidence:  0.9066666666666667
# Lift: 52.28
#
# ['federal', 'boca', 'apura'] -> ['15', 'fraudes', 'livre', 'policia', 'anos', 'operacao']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['fraudes', 'boca', 'apura'] -> ['15', 'livre', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 55.20248447204969
#
# ['boca', 'apura', 'livre'] -> ['15', 'fraudes', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 50.78628571428572
#
# ['boca', 'apura', 'operacao'] -> ['15', 'fraudes', 'livre', 'federal', 'policia', 'anos']
# Confidence:  0.9577464788732394
# Lift: 54.42498469075321
#
# ['policia', 'boca', 'apura'] -> ['15', 'fraudes', 'livre', 'federal', 'anos', 'operacao']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['fraudes', 'federal', 'apura'] -> ['boca', '15', 'livre', 'policia', 'anos', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 52.21856639247943
#
# ['federal', 'livre', 'apura'] -> ['boca', '15', 'fraudes', 'policia', 'anos', 'operacao']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['federal', 'apura', 'operacao'] -> ['boca', '15', 'fraudes', 'livre', 'policia', 'anos']
# Confidence:  0.9315068493150684
# Lift: 52.93388921977367
#
# ['federal', 'apura', 'policia'] -> ['boca', '15', 'fraudes', 'livre', 'anos', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 51.47258687258687
#
# ['fraudes', 'livre', 'apura'] -> ['boca', '15', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.002520478890986
#
# ['fraudes', 'apura', 'operacao'] -> ['boca', '15', 'livre', 'policia', 'federal', 'anos']
# Confidence:  0.9066666666666667
# Lift: 51.522318840579715
#
# ['fraudes', 'policia', 'apura'] -> ['boca', '15', 'livre', 'federal', 'anos', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 52.21856639247943
#
# ['livre', 'apura', 'operacao'] -> ['boca', '15', 'fraudes', 'federal', 'policia', 'anos']
# Confidence:  0.9714285714285714
# Lift: 55.20248447204969
#
# ['policia', 'livre', 'apura'] -> ['boca', '15', 'fraudes', 'federal', 'anos', 'operacao']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['policia', 'apura', 'operacao'] -> ['boca', '15', 'fraudes', 'livre', 'federal', 'anos']
# Confidence:  0.9315068493150684
# Lift: 52.93388921977367
#
# ['fraudes', 'federal', 'boca'] -> ['15', 'livre', 'apura', 'policia', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['federal', 'boca', 'livre'] -> ['15', 'fraudes', 'apura', 'policia', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 52.17769080234833
#
# ['federal', 'boca', 'operacao'] -> ['15', 'fraudes', 'livre', 'apura', 'policia', 'anos']
# Confidence:  0.9714285714285714
# Lift: 56.01428571428571
#
# ['federal', 'boca', 'policia'] -> ['15', 'fraudes', 'livre', 'apura', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 55.20248447204969
#
# ['fraudes', 'boca', 'livre'] -> ['15', 'apura', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 52.17769080234833
#
# ['fraudes', 'boca', 'operacao'] -> ['15', 'livre', 'apura', 'federal', 'policia', 'anos']
# Confidence:  0.9577464788732394
# Lift: 55.22535211267605
#
# ['fraudes', 'policia', 'boca'] -> ['15', 'livre', 'apura', 'federal', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['operacao', 'boca', 'livre'] -> ['15', 'fraudes', 'apura', 'federal', 'policia', 'anos']
# Confidence:  0.9315068493150684
# Lift: 49.357275083302476
#
# ['policia', 'boca', 'livre'] -> ['15', 'fraudes', 'apura', 'federal', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 52.17769080234833
#
# ['policia', 'boca', 'operacao'] -> ['15', 'fraudes', 'livre', 'apura', 'federal', 'anos']
# Confidence:  0.9714285714285714
# Lift: 56.01428571428571
#
# ['fraudes', 'federal', 'livre'] -> ['boca', '15', 'apura', 'policia', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['fraudes', 'federal', 'operacao'] -> ['boca', '15', 'livre', 'apura', 'policia', 'anos']
# Confidence:  0.9066666666666667
# Lift: 52.28
#
# ['fraudes', 'federal', 'policia'] -> ['boca', '15', 'livre', 'apura', 'anos', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 50.11804511278196
#
# ['federal', 'livre', 'operacao'] -> ['boca', '15', 'fraudes', 'apura', 'policia', 'anos']
# Confidence:  0.9714285714285714
# Lift: 56.01428571428571
#
# ['federal', 'livre', 'policia'] -> ['boca', '15', 'fraudes', 'apura', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 54.413877551020406
#
# ['federal', 'policia', 'operacao'] -> ['boca', '15', 'fraudes', 'livre', 'apura', 'anos']
# Confidence:  0.8717948717948718
# Lift: 49.540691192865104
#
# ['fraudes', 'livre', 'operacao'] -> ['boca', '15', 'apura', 'federal', 'policia', 'anos']
# Confidence:  0.9714285714285714
# Lift: 56.01428571428571
#
# ['fraudes', 'policia', 'livre'] -> ['boca', '15', 'apura', 'federal', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['fraudes', 'policia', 'operacao'] -> ['boca', '15', 'livre', 'apura', 'federal', 'anos']
# Confidence:  0.9066666666666667
# Lift: 52.28
#
# ['policia', 'livre', 'operacao'] -> ['boca', '15', 'fraudes', 'apura', 'federal', 'anos']
# Confidence:  0.9714285714285714
# Lift: 56.01428571428571
#
# ['apura', 'boca', '15', 'anos'] -> ['fraudes', 'livre', 'federal', 'policia', 'operacao']
# Confidence:  0.9577464788732394
# Lift: 54.42498469075321
#
# ['apura', '15', 'anos', 'federal'] -> ['boca', 'fraudes', 'livre', 'policia', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 52.21856639247943
#
# ['fraudes', 'apura', '15', 'anos'] -> ['boca', 'livre', 'policia', 'federal', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 50.11804511278196
#
# ['apura', 'livre', '15', 'anos'] -> ['boca', 'fraudes', 'federal', 'policia', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 55.20248447204969
#
# ['apura', '15', 'anos', 'operacao'] -> ['boca', 'fraudes', 'livre', 'federal', 'policia']
# Confidence:  0.8947368421052633
# Lift: 50.84439359267735
#
# ['apura', '15', 'anos', 'policia'] -> ['boca', 'fraudes', 'livre', 'federal', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 52.21856639247943
#
# ['federal', 'boca', '15', 'anos'] -> ['fraudes', 'livre', 'apura', 'policia', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['fraudes', 'boca', '15', 'anos'] -> ['livre', 'apura', 'federal', 'policia', 'operacao']
# Confidence:  0.9577464788732394
# Lift: 55.22535211267605
#
# ['boca', '15', 'anos', 'livre'] -> ['fraudes', 'apura', 'federal', 'policia', 'operacao']
# Confidence:  0.9444444444444444
# Lift: 50.7283105022831
#
# ['boca', '15', 'anos', 'operacao'] -> ['fraudes', 'livre', 'apura', 'federal', 'policia']
# Confidence:  0.9315068493150684
# Lift: 53.71232876712328
#
# ['policia', 'boca', '15', 'anos'] -> ['fraudes', 'livre', 'apura', 'federal', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['fraudes', 'federal', '15', 'anos'] -> ['boca', 'livre', 'apura', 'policia', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 51.5921052631579
#
# ['federal', 'livre', '15', 'anos'] -> ['boca', 'fraudes', 'apura', 'policia', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['federal', '15', 'anos', 'operacao'] -> ['boca', 'fraudes', 'livre', 'apura', 'policia']
# Confidence:  0.9066666666666667
# Lift: 52.28
#
# ['federal', '15', 'anos', 'policia'] -> ['boca', 'fraudes', 'livre', 'apura', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 50.84439359267735
#
# ['fraudes', 'livre', '15', 'anos'] -> ['boca', 'apura', 'federal', 'policia', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 56.01428571428571
#
# ['fraudes', '15', 'anos', 'operacao'] -> ['boca', 'livre', 'apura', 'policia', 'federal']
# Confidence:  0.8717948717948718
# Lift: 50.26923076923077
#
# ['fraudes', 'policia', '15', 'anos'] -> ['boca', 'livre', 'apura', 'federal', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 51.5921052631579
#
# ['livre', '15', 'anos', 'operacao'] -> ['boca', 'fraudes', 'apura', 'federal', 'policia']
# Confidence:  0.9444444444444444
# Lift: 54.45833333333333
#
# ['policia', 'livre', '15', 'anos'] -> ['boca', 'fraudes', 'apura', 'federal', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['policia', '15', 'anos', 'operacao'] -> ['boca', 'fraudes', 'livre', 'apura', 'federal']
# Confidence:  0.9066666666666667
# Lift: 52.28
#
# ['federal', 'boca', '15', 'apura'] -> ['fraudes', 'livre', 'policia', 'anos', 'operacao']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['fraudes', 'boca', '15', 'apura'] -> ['livre', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 55.20248447204969
#
# ['boca', '15', 'apura', 'livre'] -> ['fraudes', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 50.78628571428572
#
# ['boca', '15', 'apura', 'operacao'] -> ['fraudes', 'livre', 'federal', 'policia', 'anos']
# Confidence:  0.9577464788732394
# Lift: 54.42498469075321
#
# ['policia', 'boca', '15', 'apura'] -> ['fraudes', 'livre', 'federal', 'anos', 'operacao']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['fraudes', 'federal', '15', 'apura'] -> ['boca', 'livre', 'policia', 'anos', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 52.21856639247943
#
# ['federal', 'livre', '15', 'apura'] -> ['boca', 'fraudes', 'policia', 'anos', 'operacao']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['federal', '15', 'apura', 'operacao'] -> ['boca', 'fraudes', 'livre', 'policia', 'anos']
# Confidence:  0.9315068493150684
# Lift: 52.93388921977367
#
# ['federal', '15', 'apura', 'policia'] -> ['boca', 'fraudes', 'livre', 'anos', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 51.47258687258687
#
# ['fraudes', 'livre', '15', 'apura'] -> ['boca', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.002520478890986
#
# ['fraudes', '15', 'apura', 'operacao'] -> ['boca', 'livre', 'policia', 'federal', 'anos']
# Confidence:  0.9066666666666667
# Lift: 51.522318840579715
#
# ['fraudes', 'policia', '15', 'apura'] -> ['boca', 'livre', 'federal', 'anos', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 52.21856639247943
#
# ['livre', '15', 'apura', 'operacao'] -> ['boca', 'fraudes', 'federal', 'policia', 'anos']
# Confidence:  0.9714285714285714
# Lift: 55.20248447204969
#
# ['policia', 'livre', '15', 'apura'] -> ['boca', 'fraudes', 'federal', 'anos', 'operacao']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['policia', '15', 'apura', 'operacao'] -> ['boca', 'fraudes', 'livre', 'federal', 'anos']
# Confidence:  0.9315068493150684
# Lift: 52.93388921977367
#
# ['fraudes', 'federal', 'boca', '15'] -> ['livre', 'apura', 'policia', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['federal', 'boca', '15', 'livre'] -> ['fraudes', 'apura', 'policia', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 52.93388921977367
#
# ['federal', 'boca', '15', 'operacao'] -> ['fraudes', 'livre', 'apura', 'policia', 'anos']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['federal', 'boca', '15', 'policia'] -> ['fraudes', 'livre', 'apura', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.002520478890986
#
# ['fraudes', 'boca', '15', 'livre'] -> ['apura', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 52.17769080234833
#
# ['fraudes', 'boca', '15', 'operacao'] -> ['livre', 'apura', 'federal', 'policia', 'anos']
# Confidence:  0.9577464788732394
# Lift: 55.22535211267605
#
# ['fraudes', 'policia', 'boca', '15'] -> ['livre', 'apura', 'federal', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['operacao', 'boca', '15', 'livre'] -> ['fraudes', 'apura', 'federal', 'policia', 'anos']
# Confidence:  0.9444444444444444
# Lift: 50.04279279279279
#
# ['policia', 'boca', '15', 'livre'] -> ['fraudes', 'apura', 'federal', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 52.93388921977367
#
# ['policia', 'boca', '15', 'operacao'] -> ['fraudes', 'livre', 'apura', 'federal', 'anos']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['fraudes', 'federal', 'livre', '15'] -> ['boca', 'apura', 'policia', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['fraudes', 'federal', '15', 'operacao'] -> ['boca', 'livre', 'apura', 'policia', 'anos']
# Confidence:  0.9066666666666667
# Lift: 52.28
#
# ['fraudes', 'federal', '15', 'policia'] -> ['boca', 'livre', 'apura', 'anos', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 50.11804511278196
#
# ['federal', 'livre', '15', 'operacao'] -> ['boca', 'fraudes', 'apura', 'policia', 'anos']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['federal', 'livre', '15', 'policia'] -> ['boca', 'fraudes', 'apura', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 55.20248447204968
#
# ['federal', 'policia', '15', 'operacao'] -> ['boca', 'fraudes', 'livre', 'apura', 'anos']
# Confidence:  0.9066666666666667
# Lift: 51.522318840579715
#
# ['fraudes', 'livre', '15', 'operacao'] -> ['boca', 'apura', 'federal', 'policia', 'anos']
# Confidence:  0.9714285714285714
# Lift: 56.01428571428571
#
# ['fraudes', 'policia', 'livre', '15'] -> ['boca', 'apura', 'federal', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['fraudes', 'policia', '15', 'operacao'] -> ['boca', 'livre', 'apura', 'federal', 'anos']
# Confidence:  0.9066666666666667
# Lift: 52.28
#
# ['policia', 'livre', '15', 'operacao'] -> ['boca', 'fraudes', 'apura', 'federal', 'anos']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['apura', 'boca', 'anos', 'federal'] -> ['15', 'fraudes', 'livre', 'policia', 'operacao']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['fraudes', 'apura', 'boca', 'anos'] -> ['15', 'livre', 'federal', 'policia', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 55.20248447204969
#
# ['apura', 'boca', 'anos', 'livre'] -> ['15', 'fraudes', 'federal', 'policia', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 50.78628571428572
#
# ['apura', 'boca', 'anos', 'operacao'] -> ['15', 'fraudes', 'livre', 'federal', 'policia']
# Confidence:  0.9577464788732394
# Lift: 54.42498469075321
#
# ['apura', 'boca', 'anos', 'policia'] -> ['15', 'fraudes', 'livre', 'federal', 'operacao']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['fraudes', 'apura', 'anos', 'federal'] -> ['boca', '15', 'livre', 'policia', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 52.21856639247943
#
# ['apura', 'livre', 'anos', 'federal'] -> ['boca', '15', 'fraudes', 'policia', 'operacao']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['apura', 'operacao', 'anos', 'federal'] -> ['boca', '15', 'fraudes', 'livre', 'policia']
# Confidence:  0.9315068493150684
# Lift: 52.93388921977367
#
# ['apura', 'policia', 'anos', 'federal'] -> ['boca', '15', 'fraudes', 'livre', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 51.47258687258687
#
# ['fraudes', 'apura', 'livre', 'anos'] -> ['boca', '15', 'federal', 'policia', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.002520478890986
#
# ['fraudes', 'apura', 'anos', 'operacao'] -> ['boca', '15', 'livre', 'policia', 'federal']
# Confidence:  0.9066666666666667
# Lift: 51.522318840579715
#
# ['fraudes', 'apura', 'anos', 'policia'] -> ['boca', '15', 'livre', 'federal', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 52.21856639247943
#
# ['apura', 'livre', 'anos', 'operacao'] -> ['boca', '15', 'fraudes', 'federal', 'policia']
# Confidence:  0.9714285714285714
# Lift: 55.20248447204969
#
# ['apura', 'livre', 'anos', 'policia'] -> ['boca', '15', 'fraudes', 'federal', 'operacao']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['apura', 'policia', 'anos', 'operacao'] -> ['boca', '15', 'fraudes', 'livre', 'federal']
# Confidence:  0.9315068493150684
# Lift: 52.93388921977367
#
# ['fraudes', 'federal', 'boca', 'anos'] -> ['15', 'livre', 'apura', 'policia', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['federal', 'boca', 'anos', 'livre'] -> ['15', 'fraudes', 'apura', 'policia', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 52.93388921977367
#
# ['federal', 'boca', 'anos', 'operacao'] -> ['15', 'fraudes', 'livre', 'apura', 'policia']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['federal', 'boca', 'anos', 'policia'] -> ['15', 'fraudes', 'livre', 'apura', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.002520478890986
#
# ['fraudes', 'boca', 'anos', 'livre'] -> ['15', 'apura', 'federal', 'policia', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 52.17769080234833
#
# ['fraudes', 'boca', 'anos', 'operacao'] -> ['15', 'livre', 'apura', 'federal', 'policia']
# Confidence:  0.9577464788732394
# Lift: 55.22535211267605
#
# ['fraudes', 'policia', 'boca', 'anos'] -> ['15', 'livre', 'apura', 'federal', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['operacao', 'boca', 'anos', 'livre'] -> ['15', 'fraudes', 'apura', 'federal', 'policia']
# Confidence:  0.9444444444444444
# Lift: 50.04279279279279
#
# ['policia', 'boca', 'anos', 'livre'] -> ['15', 'fraudes', 'apura', 'federal', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 52.93388921977367
#
# ['policia', 'boca', 'anos', 'operacao'] -> ['15', 'fraudes', 'livre', 'apura', 'federal']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['fraudes', 'federal', 'livre', 'anos'] -> ['boca', '15', 'apura', 'policia', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['fraudes', 'federal', 'anos', 'operacao'] -> ['boca', '15', 'livre', 'apura', 'policia']
# Confidence:  0.9066666666666667
# Lift: 52.28
#
# ['fraudes', 'federal', 'anos', 'policia'] -> ['boca', '15', 'livre', 'apura', 'operacao']
# Confidence:  0.8947368421052633
# Lift: 50.11804511278196
#
# ['federal', 'livre', 'anos', 'operacao'] -> ['boca', '15', 'fraudes', 'apura', 'policia']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['federal', 'livre', 'anos', 'policia'] -> ['boca', '15', 'fraudes', 'apura', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 55.20248447204968
#
# ['federal', 'policia', 'anos', 'operacao'] -> ['boca', '15', 'fraudes', 'livre', 'apura']
# Confidence:  0.9066666666666667
# Lift: 51.522318840579715
#
# ['fraudes', 'livre', 'anos', 'operacao'] -> ['boca', '15', 'apura', 'federal', 'policia']
# Confidence:  0.9714285714285714
# Lift: 56.01428571428571
#
# ['fraudes', 'policia', 'livre', 'anos'] -> ['boca', '15', 'apura', 'federal', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['fraudes', 'policia', 'anos', 'operacao'] -> ['boca', '15', 'livre', 'apura', 'federal']
# Confidence:  0.9066666666666667
# Lift: 52.28
#
# ['policia', 'livre', 'anos', 'operacao'] -> ['boca', '15', 'fraudes', 'apura', 'federal']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['fraudes', 'federal', 'boca', 'apura'] -> ['15', 'livre', 'policia', 'anos', 'operacao']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['federal', 'boca', 'apura', 'livre'] -> ['15', 'fraudes', 'policia', 'anos', 'operacao']
# Confidence:  1.0
# Lift: 52.28
#
# ['federal', 'boca', 'apura', 'operacao'] -> ['15', 'fraudes', 'livre', 'policia', 'anos']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['federal', 'boca', 'apura', 'policia'] -> ['15', 'fraudes', 'livre', 'anos', 'operacao']
# Confidence:  1.0
# Lift: 56.01428571428571
#
# ['fraudes', 'boca', 'apura', 'livre'] -> ['15', 'federal', 'policia', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 51.522318840579715
#
# ['fraudes', 'boca', 'apura', 'operacao'] -> ['15', 'livre', 'federal', 'policia', 'anos']
# Confidence:  0.9714285714285714
# Lift: 55.20248447204969
#
# ['fraudes', 'policia', 'boca', 'apura'] -> ['15', 'livre', 'federal', 'anos', 'operacao']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['operacao', 'boca', 'apura', 'livre'] -> ['15', 'fraudes', 'federal', 'policia', 'anos']
# Confidence:  0.9714285714285714
# Lift: 50.11804511278196
#
# ['policia', 'boca', 'apura', 'livre'] -> ['15', 'fraudes', 'federal', 'anos', 'operacao']
# Confidence:  1.0
# Lift: 52.28
#
# ['policia', 'boca', 'apura', 'operacao'] -> ['15', 'fraudes', 'livre', 'federal', 'anos']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['fraudes', 'federal', 'livre', 'apura'] -> ['boca', '15', 'policia', 'anos', 'operacao']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['fraudes', 'federal', 'apura', 'operacao'] -> ['boca', '15', 'livre', 'policia', 'anos']
# Confidence:  0.9315068493150684
# Lift: 52.93388921977367
#
# ['fraudes', 'federal', 'apura', 'policia'] -> ['boca', '15', 'livre', 'anos', 'operacao']
# Confidence:  0.9189189189189189
# Lift: 50.04279279279279
#
# ['federal', 'livre', 'apura', 'operacao'] -> ['boca', '15', 'fraudes', 'policia', 'anos']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['federal', 'livre', 'apura', 'policia'] -> ['boca', '15', 'fraudes', 'anos', 'operacao']
# Confidence:  1.0
# Lift: 55.225352112676056
#
# ['federal', 'policia', 'apura', 'operacao'] -> ['boca', '15', 'fraudes', 'livre', 'anos']
# Confidence:  0.9315068493150684
# Lift: 52.17769080234833
#
# ['fraudes', 'livre', 'apura', 'operacao'] -> ['boca', '15', 'federal', 'policia', 'anos']
# Confidence:  0.9855072463768115
# Lift: 56.002520478890986
#
# ['fraudes', 'policia', 'livre', 'apura'] -> ['boca', '15', 'federal', 'anos', 'operacao']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['fraudes', 'policia', 'apura', 'operacao'] -> ['boca', '15', 'livre', 'federal', 'anos']
# Confidence:  0.9315068493150684
# Lift: 52.93388921977367
#
# ['policia', 'livre', 'apura', 'operacao'] -> ['boca', '15', 'fraudes', 'federal', 'anos']
# Confidence:  1.0
# Lift: 56.826086956521735
#
# ['fraudes', 'federal', 'boca', 'livre'] -> ['15', 'apura', 'policia', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 52.93388921977367
#
# ['fraudes', 'federal', 'boca', 'operacao'] -> ['15', 'livre', 'apura', 'policia', 'anos']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['fraudes', 'federal', 'boca', 'policia'] -> ['15', 'livre', 'apura', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 55.20248447204968
#
# ['federal', 'operacao', 'boca', 'livre'] -> ['15', 'fraudes', 'apura', 'policia', 'anos']
# Confidence:  0.9714285714285714
# Lift: 51.47258687258687
#
# ['policia', 'federal', 'boca', 'livre'] -> ['15', 'fraudes', 'apura', 'anos', 'operacao']
# Confidence:  0.9714285714285714
# Lift: 50.78628571428572
#
# ['policia', 'federal', 'boca', 'operacao'] -> ['15', 'fraudes', 'livre', 'apura', 'anos']
# Confidence:  0.9714285714285714
# Lift: 55.20248447204969
#
# ['fraudes', 'operacao', 'boca', 'livre'] -> ['15', 'apura', 'federal', 'policia', 'anos']
# Confidence:  0.9714285714285714
# Lift: 51.47258687258687
#
# ['fraudes', 'policia', 'boca', 'livre'] -> ['15', 'apura', 'federal', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 52.93388921977367
#
# ['fraudes', 'policia', 'boca', 'operacao'] -> ['15', 'livre', 'apura', 'federal', 'anos']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['policia', 'operacao', 'boca', 'livre'] -> ['15', 'fraudes', 'apura', 'federal', 'anos']
# Confidence:  0.9714285714285714
# Lift: 51.47258687258687
#
# ['fraudes', 'federal', 'livre', 'operacao'] -> ['boca', '15', 'apura', 'policia', 'anos']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ['fraudes', 'federal', 'livre', 'policia'] -> ['boca', '15', 'apura', 'anos', 'operacao']
# Confidence:  0.9855072463768115
# Lift: 54.424984690753206
#
# ['fraudes', 'federal', 'policia', 'operacao'] -> ['boca', '15', 'livre', 'apura', 'anos']
# Confidence:  0.9066666666666667
# Lift: 50.78628571428572
#
# ['policia', 'federal', 'livre', 'operacao'] -> ['boca', '15', 'fraudes', 'apura', 'anos']
# Confidence:  0.9714285714285714
# Lift: 54.413877551020406
#
# ['fraudes', 'policia', 'livre', 'operacao'] -> ['boca', '15', 'apura', 'federal', 'anos']
# Confidence:  0.9855072463768115
# Lift: 56.826086956521735
#
# ----------------------------------------------------------------------------------
#
# Concluido!

# %% [markdown]
# ## Operação "Boca Livre" da Polícia Federal apura 15 anos de fraudes na Lei Rouanet

# %%
getAssociationRules(tweets_2021, 0.018, 0.7, 1, 4, 10)
# Out:
# Palavras Associadas:  ['projetos', 'mario', 'passaporte', 'frias']  Support:  0.023450586264656615
# ----------------------------------------------------------------------------------
#
# ['passaporte', 'frias'] -> ['projetos', 'mario']
# Confidence:  0.7216494845360825
# Lift: 25.953297726990435
#
# ['projetos', 'frias'] -> ['mario', 'passaporte']
# Confidence:  0.7777777777777778
# Lift: 26.086142322097377
#
# ['mario', 'passaporte'] -> ['projetos', 'frias']
# Confidence:  0.7865168539325842
# Lift: 26.086142322097377
#
# ['projetos', 'mario'] -> ['frias', 'passaporte']
# Confidence:  0.8433734939759036
# Lift: 25.953297726990435
#
# ----------------------------------------------------------------------------------
#
#
#
# Palavras Associadas:  ['vacina', 'mario', 'passaporte', 'frias']  Support:  0.019765494137353432
# ----------------------------------------------------------------------------------
#
# ['vacina', 'frias'] -> ['mario', 'passaporte']
# Confidence:  0.8309859154929576
# Lift: 27.870707390409873
#
# ['mario', 'vacina'] -> ['frias', 'passaporte']
# Confidence:  0.8939393939393938
# Lift: 27.509372071227737
#
# ----------------------------------------------------------------------------------
#
# Concluido!

# %% [markdown]
# ## Mario Frias proíbe passaporte da vacina em projetos da Lei Rouanet

# %%
getAssociationRules(tweets_2019, 0.015, 0.7, 1, 4, 10)
# Out:
# Palavras Associadas:  ['miami', 'doria', 'bia', 'exposicao']  Support:  0.01757506015273564
# ----------------------------------------------------------------------------------
#
# ['bia'] -> ['exposicao', 'doria', 'miami']
# Confidence:  0.9545454545454545
# Lift: 54.3125
#
# ['doria'] -> ['exposicao', 'bia', 'miami']
# Confidence:  0.8842105263157893
# Lift: 50.310526315789474
#
# ['exposicao'] -> ['doria', 'miami', 'bia']
# Confidence:  0.9438202247191011
# Lift: 53.70224719101124
#
# ['miami'] -> ['doria', 'exposicao', 'bia']
# Confidence:  0.9438202247191011
# Lift: 52.76010250344963
#
# ['doria', 'bia'] -> ['exposicao', 'miami']
# Confidence:  0.9599999999999999
# Lift: 54.62285714285714
#
# ['bia', 'exposicao'] -> ['doria', 'miami']
# Confidence:  0.982456140350877
# Lift: 55.900584795321635
#
# ['bia', 'miami'] -> ['doria', 'exposicao']
# Confidence:  1.0
# Lift: 55.900584795321635
#
# ['doria', 'exposicao'] -> ['bia', 'miami']
# Confidence:  0.982456140350877
# Lift: 55.900584795321635
#
# ['doria', 'miami'] -> ['bia', 'exposicao']
# Confidence:  1.0
# Lift: 55.900584795321635
#
# ['miami', 'exposicao'] -> ['doria', 'bia']
# Confidence:  1.0
# Lift: 54.62285714285714
#
# ----------------------------------------------------------------------------------
#
# Concluido!

# %% [markdown]
# ## Bia Doria usou lei rouanet para fazer exposição em miami
